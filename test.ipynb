# %%
import pandas as pd
import datetime
from pandas._libs.tslibs.parsing import DateParseError
import json

# %%
df = pd.read_csv("/app/data/202309.csv",dtype=str)
# df2 = pd.read_csv("/app/data/202307.csv")
# print(type(df2["date"][0]))
# type(pd.to_datetime(df["date"][0]))
data = pd.DataFrame(columns=("date","part","exercise","weight","number_of_times"))
part = ["背中","胸","脚","腹筋","肩","腕"]

# %%
# try:
#     t = type(pd.to_datetime(df["date"][1]))
# except DateParseError:
#     print(123455656)
with open('app/data/data.json') as f:
    ex_json = json.load(f)
    
part_list = []
date_list = []
ex_list = []
training_list = []
# pd.to_datetime(df["date"][1])
for i in range(len(df)):
    # if df["date"][i] == "11111":

    try:
        training_date = pd.to_datetime(df["date"][i])
        each_dict = {"date": df["date"][i]}
    except DateParseError:
        if df["date"][i] in ex_json["part"]:
            each_dict["part"] = df["date"][i]
            each_dict["exercise"] = {}
        if df["date"][i] in each_dict["part"]:
            each_dict["exercise"][df["date"][i+1]] = []
            part = df["date"][i+1]
            for j in range(i+2,i+10):
                if df["date"][j].count("×")==1:
                    each_dict["exercise"][part].append(df["date"][j].split("×"))
                else:
                    training_list.append(each_dict)
                    i += len()
            
        # date = training_date.year + '-' + training_date.month + '-' + training_date.day
        # each_dict = {
        #     "date": 
        #     training_date, "part": part, "exercise":{df["date"][i+2]:[]}
        # }
        # セット数（上限10を想定
        # if  each_dict["part"] == each_dict["part"]:
        #     for j in range(i+2,i+10):
        #         if df["date"][j].count("×") == 1:
        #             each_dict["exercise"][df["date"][i+2]].append(df["date"][j].split("×"))
        #         else:
        #             training_list.append(each_dict)
        #             break
    
    # except IndexError:
    #     continue
    # except KeyError:
    #     continue
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[458], line 17
#      16 try:
# ---> 17     training_date = pd.to_datetime(df["date"][i])
#      18     each_dict = {"date": df["date"][i]}
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py:1101, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1100 else:
# -> 1101     result = convert_listlike(np.array([arg]), format)[0]
#    1102     if isinstance(arg, bool) and isinstance(result, np.bool_):
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 435 result, tz_parsed = objects_to_datetime64(
# ...

# %%
# JSON 文字列が空でないことを確認し、適切な JSON 形式であることを確認する
json_string = '{"name": [], "age": 30, "city": "New York"}'

# JSON 文字列を解析する
try:
    data = json.loads(json_string)
    print(data)
except json.JSONDecodeError as e:
    print("JSON 解析エラー:", e)
# Out:
# {'name': [], 'age': 30, 'city': 'New York'}

# %%
df = pd.read_csv("/app/data/202403.csv",sep=',')
df.to_excel("/app/data/トレーニング管理.xlsx",index=False,sheet_name='202403')
df
# Out:
#           date part exercise  weight  number_of_times
# 0   2024-03-01   背中   デッドリフト   110.0                4
# 1   2024-03-01   背中   デッドリフト   100.0                7
# 2   2024-03-01   背中   デッドリフト   100.0                5
# 3   2024-03-01   背中   デッドリフト    90.0                8
# 4   2024-03-01   背中   デッドリフト    80.0                8
# ..         ...  ...      ...     ...              ...
# 78  2024-03-14    脚    スクワット   100.0                2
# 79  2024-03-14    脚   レッグプレス   118.0                8
# 80  2024-03-14    脚   レッグプレス   118.0                8
# 81  2024-03-14    脚   レッグプレス   127.0                5
# 82  2024-03-14    脚   レッグプレス   127.0                6
#
# [83 rows x 5 columns]

# %%
with pd.ExcelWriter("/app/data/トレーニング管理.xlsx", engine="openpyxl", mode="a") as writer:
	df = pd.read_csv("/app/data/202404.csv",sep=',')
	df.to_excel(writer,index=False,sheet_name='202404')
